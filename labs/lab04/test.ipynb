# %%
import numpy as np
import matplotlib.pyplot as plt
import math

C = 20
g = 5
start_value = 1
last_value = 20
lambda2 = 2
mu = 1.5
rho2 = 0
step = 0.5

def compute_probabilities(C, rho1, rho2, g):
    p = np.zeros((g+1, C+1))

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 + n2 <= C:
                p[0][0] += (rho1 ** n1) * (rho2 ** n2) / (math.factorial(n1) * math.factorial(n2))

    p[0][0] = 1 / p[0][0]

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 == n2 == 0:
                continue
            if n1 + n2 <= C:
                p[n1][n2] = p[0][0] * (rho1 ** n1) * (rho2 ** n2) / (math.factorial(n1) * math.factorial(n2))
    return p

lambda1 = np.arange(start_value, last_value + step, step)
rho1 = lambda1 / mu
rho2 = lambda2 / mu

B1 = np.zeros(len(lambda1))
B2 = np.zeros(len(lambda1))
N = np.zeros(len(lambda1))

for i in range(len(lambda1)):
    p = compute_probabilities(C, rho1[i], rho2, g)

    # Print the entire array p
    print(f"Probabilities p for lambda1 = {lambda1[i]}:")
    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 + n2 <= C:
                print(f"p({n1},{n2}) = {p[n1][n2]}")
    
    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 == g or n1 + n2 == C:
                B1[i] += p[n1][n2]
            if n1 + n2 == C:
                B2[i] += p[n1][n2]
            if n1 + n2 <= C:
                N[i] += (n1 + n2) * p[n1][n2]

    # Print blocking probabilities and average number
    print(f"B1 for lambda1 = {lambda1[i]}: {B1[i]}")
    print(f"B2 for lambda1 = {lambda1[i]}: {B2[i]}")
    print(f"N for lambda1 = {lambda1[i]}: {N[i]}")
# Out:
# Probabilities p for lambda1 = 1.0:
# p(0,0) = 0.1353446356433055
# p(0,1) = 0.180459514191074
# p(0,2) = 0.12030634279404934
# p(0,3) = 0.053469485686244135
# p(0,4) = 0.017823161895414715
# p(0,5) = 0.00475284317211059
# p(0,6) = 0.001056187371580131
# p(0,7) = 0.00020117854696764397
# p(0,8) = 3.352975782794066e-05
# p(0,9) = 4.967371530065284e-06
# p(0,10) = 6.623162040087045e-07
# p(0,11) = 8.028075200105508e-08
# p(0,12) = 8.920083555672786e-09
# p(0,13) = 9.148803646843883e-10
# p(0,14) = 8.713146330327506e-11
# p(0,15) = 7.745018960291118e-12
# p(0,16) = 6.454182466909264e-13
# p(0,17) = 5.0621038956151083e-14
# p(0,18) = 3.749706589344524e-15
# p(0,19) = 2.6313730451540523e-16
# p(0,20) = 1.754248696769368e-17
# p(1,0) = 0.090229757095537
# p(1,1) = 0.12030634279404934
# p(1,2) = 0.08020422852936622
# p(1,3) = 0.03564632379082942
# p(1,4) = 0.011882107930276475
# p(1,5) = 0.0031685621147403927
# p(1,6) = 0.0007041249143867539
# p(1,7) = 0.00013411903131176268
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

C = 20
g = 5
start_value = 1
last_value = 20
lambda2 = 2
mu = 1.5
rho2 = 0
step = 0.5

def compute_probabilities(C, rho1, rho2, g):
    p = np.zeros((g+1, C+1))

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 + n2 <= C:
                p[0][0] += (rho1 ** n1) * (rho2 ** n2) / (math.factorial(n1) * math.factorial(n2))

    p[0][0] = 1 / p[0][0]

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 == n2 == 0:
                continue
            if n1 + n2 <= C:
                p[n1][n2] = p[0][0] * (rho1 ** n1) * (rho2 ** n2) / (math.factorial(n1) * math.factorial(n2))

    # Check and normalize the sum of probabilities to 1
    total_probability = np.sum(p)
    if total_probability != 1:
        p = p / total_probability
    return p

lambda1 = np.arange(start_value, last_value + step, step)
rho1 = lambda1 / mu
rho2 = lambda2 / mu

B1 = np.zeros(len(lambda1))
B2 = np.zeros(len(lambda1))
N = np.zeros(len(lambda1))

for i in range(len(lambda1)):
    p = compute_probabilities(C, rho1[i], rho2, g)

    # Print the entire array p
    print(f"Probabilities p for lambda1 = {lambda1[i]}:")
    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 + n2 <= C:
                print(f"p({n1},{n2}) = {p[n1][n2]}")

    # Ensure the sum of probabilities is 1
    total_probability = np.sum(p)
    print(f"Total Probability for lambda1 = {lambda1[i]}: {total_probability}")

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 == g or n1 + n2 == C:
                B1[i] += p[n1][n2]
            if n1 + n2 == C:
                B2[i] += p[n1][n2]
            if n1 + n2 <= C:
                N[i] += (n1 + n2) * p[n1][n2]

    # Print blocking probabilities and average number
    print(f"B1 for lambda1 = {lambda1[i]}: {B1[i]}")
    print(f"B2 for lambda1 = {lambda1[i]}: {B2[i]}")
    print(f"N for lambda1 = {lambda1[i]}: {N[i]}")
# Out:
# Probabilities p for lambda1 = 1.0:
# p(0,0) = 0.13534463564330548
# p(0,1) = 0.18045951419107398
# p(0,2) = 0.12030634279404931
# p(0,3) = 0.05346948568624412
# p(0,4) = 0.01782316189541471
# p(0,5) = 0.004752843172110589
# p(0,6) = 0.0010561873715801307
# p(0,7) = 0.0002011785469676439
# p(0,8) = 3.3529757827940656e-05
# p(0,9) = 4.967371530065283e-06
# p(0,10) = 6.623162040087044e-07
# p(0,11) = 8.028075200105506e-08
# p(0,12) = 8.920083555672784e-09
# p(0,13) = 9.148803646843881e-10
# p(0,14) = 8.713146330327504e-11
# p(0,15) = 7.745018960291117e-12
# p(0,16) = 6.454182466909263e-13
# p(0,17) = 5.062103895615107e-14
# p(0,18) = 3.7497065893445234e-15
# p(0,19) = 2.631373045154052e-16
# p(0,20) = 1.7542486967693677e-17
# p(1,0) = 0.09022975709553699
# p(1,1) = 0.12030634279404931
# p(1,2) = 0.0802042285293662
# p(1,3) = 0.035646323790829416
# p(1,4) = 0.011882107930276472
# p(1,5) = 0.003168562114740392
# p(1,6) = 0.0007041249143867538
# p(1,7) = 0.00013411903131176265
# ...

# %%
plt.figure(figsize=(10, 10))
plt.plot(lambda1, B1, label="B_1", color='green')
plt.plot(lambda1, B2, label="B_2", color='black')
plt.title("Probability of Blocking")
plt.xlabel("Lambda_1")
plt.ylabel("Amount")
plt.legend()

plt.figure(figsize=(10, 10))
plt.plot(lambda1, N, label="NN")
plt.title("Average Number of Requests")
plt.xlabel("Lambda_1")
plt.ylabel("Time")
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

C = 20
g = 5
lambda2 = 2
mu = 1.5
step = 0.5

def compute_probabilities(C, rho1, rho2, g):
    p = np.zeros((g+1, C+1))

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 + n2 <= C:
                p[0][0] += (rho1 ** n1) * (rho2 ** n2) / (math.factorial(n1) * math.factorial(n2))

    p[0][0] = 1 / p[0][0]

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 == n2 == 0:
                continue
            if n1 + n2 <= C:
                p[n1][n2] = p[0][0] * (rho1 ** n1) * (rho2 ** n2) / (math.factorial(n1) * math.factorial(n2))
    return p

lambda2 = 2
mu = 1.5

lambda1_values = np.arange(1, 20.5, step)
B1_values = []
B2_values = []
N_values = []

for lambda1 in lambda1_values:
    rho1 = lambda1 / mu
    rho2 = lambda2 / mu
    p = compute_probabilities(C, rho1, rho2, g)

    B1 = 0
    B2 = 0
    N = 0

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 == g or n1 + n2 == C:
                B1 += p[n1][n2]
            if n1 + n2 == C:
                B2 += p[n1][n2]
            if n1 + n2 <= C:
                N += (n1 + n2) * p[n1][n2]

    B1_values.append(B1)
    B2_values.append(B2)
    N_values.append(N)

    print(f"Lambda1 = {lambda1}, B1 = {B1}, B2 = {B2}, N = {N}")

# Plot B1, B2, and N
plt.figure(figsize=(10, 6))
plt.plot(lambda1_values, B1_values, label="B1", color='green')
plt.plot(lambda1_values, B2_values, label="B2", color='blue')
plt.plot(lambda1_values, N_values, label="N", color='red')
plt.title("Blocking Probabilities B1 and B2, and Average Number N vs. Lambda1")
plt.xlabel("Lambda1")
plt.ylabel("B1, B2, and N")
plt.legend()
plt.grid()

plt.show()
# Out:
# Lambda1 = 1.0, B1 = 0.000563459642211198, B2 = 1.733745915125876e-14, N = 1.9996243602385038
# Lambda1 = 1.5, B1 = 0.0030674846625994, B2 = 7.314368022573142e-14, N = 2.3302658486706385
# Lambda1 = 2.0, B1 = 0.009280069600565452, B2 = 1.9592476583378587e-13, N = 2.6542932405323185
# Lambda1 = 2.5, B1 = 0.020390186611054267, B2 = 4.0103465353469605e-13, N = 2.966016355647712
# Lambda1 = 3.0, B1 = 0.03669724770650981, B2 = 6.891165684192906e-13, N = 3.2599388379193956
# Lambda1 = 3.5, B1 = 0.05772784414488682, B2 = 1.0492954900152698e-12, N = 3.5319683636605297
# Lambda1 = 4.0, B1 = 0.0825456963786671, B2 = 1.4645865449488603e-12, N = 3.779878142988269
# Lambda1 = 4.5, B1 = 0.11005434782621226, B2 = 1.916631062639028e-12, N = 4.00317028985214
# Lambda1 = 5.0, B1 = 0.1392059691520862, B2 = 2.3887074678486952e-12, N = 4.2026467694898635
# Lambda1 = 5.5, B1 = 0.16910975632818637, B2 = 2.86712144537649e-12, N = 4.379930893459492
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

C = 20
g = 5
lambda2 = 2
mu = 1.5
step = 0.5

def compute_probabilities(C, rho1, rho2, g):
    p = np.zeros((g+1, C+1))

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 + n2 <= C:
                p[0][0] += (rho1 ** n1) * (rho2 ** n2) / (math.factorial(n1) * math.factorial(n2))

    p[0][0] = 1 / p[0][0]

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 == n2 == 0:
                continue
            if n1 + n2 <= C:
                p[n1][n2] = p[0][0] * (rho1 ** n1) * (rho2 ** n2) / (math.factorial(n1) * math.factorial(n2))
    return p

lambda2 = 2
mu = 1.5

lambda1_values = np.arange(1, 20.5, step)
B1_values = []
B2_values = []
N_values = []
p_values = []

for lambda1 in lambda1_values:
    rho1 = lambda1 / mu
    rho2 = lambda2 / mu
    p = compute_probabilities(C, rho1, rho2, g)

    B1 = 0
    B2 = 0
    N = 0

    for n1 in range(g+1):
        for n2 in range(C+1):
            if n1 == g or n1 + n2 == C:
                B1 += p[n1][n2]
            if n1 + n2 == C:
                B2 += p[n1][n2]
            if n1 + n2 <= C:
                N += (n1 + n2) * p[n1][n2]

    B1_values.append(B1)
    B2_values.append(B2)
    N_values.append(N)
    p_values.append(p)

    print(f"Lambda1 = {lambda1}, B1 = {B1}, B2 = {B2}, N = {N}")

# Plot B1, B2, and N
plt.figure(figsize=(10, 6))
plt.plot(lambda1_values, B1_values, label="B1", color='green')
plt.plot(lambda1_values, B2_values, label="B2", color='blue')
plt.plot(lambda1_values, N_values, label="N", color='red')
plt.title("Blocking Probabilities B1 and B2, and Average Number N vs. Lambda1")
plt.xlabel("Lambda1")
plt.ylabel("B1, B2, and N")
plt.legend()
plt.grid()

plt.show()
# Out:
# Lambda1 = 1.0, B1 = 0.000563459642211198, B2 = 1.733745915125876e-14, N = 1.9996243602385038
# Lambda1 = 1.5, B1 = 0.0030674846625994, B2 = 7.314368022573142e-14, N = 2.3302658486706385
# Lambda1 = 2.0, B1 = 0.009280069600565452, B2 = 1.9592476583378587e-13, N = 2.6542932405323185
# Lambda1 = 2.5, B1 = 0.020390186611054267, B2 = 4.0103465353469605e-13, N = 2.966016355647712
# Lambda1 = 3.0, B1 = 0.03669724770650981, B2 = 6.891165684192906e-13, N = 3.2599388379193956
# Lambda1 = 3.5, B1 = 0.05772784414488682, B2 = 1.0492954900152698e-12, N = 3.5319683636605297
# Lambda1 = 4.0, B1 = 0.0825456963786671, B2 = 1.4645865449488603e-12, N = 3.779878142988269
# Lambda1 = 4.5, B1 = 0.11005434782621226, B2 = 1.916631062639028e-12, N = 4.00317028985214
# Lambda1 = 5.0, B1 = 0.1392059691520862, B2 = 2.3887074678486952e-12, N = 4.2026467694898635
# Lambda1 = 5.5, B1 = 0.16910975632818637, B2 = 2.86712144537649e-12, N = 4.379930893459492
# ...
